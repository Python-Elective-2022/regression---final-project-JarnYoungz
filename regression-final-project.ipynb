# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,r2_score

# %%
path_to_file = '../input/house-prices-advanced-regression-techniques/train.csv'
df = pd.read_csv(path_to_file)

df.head()


#print(df.describe())


fig, ax = plt.subplots(figsize=(10, 6))
ax.scatter(x = df['OverallQual'], y = df['SalePrice'])
plt.title("Relationship of Sale Price Scores to Overall Quality")
plt.xlabel("Overall Quality")
plt.ylabel("SalePrice")

plt.show()

# %%
y = df['SalePrice'].values.reshape(-1, 1)
X = df['OverallQual'].values.reshape(-1, 1)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2)

# %%
# Create a class instance to do the calculations
regressor = LinearRegression()
# And run to get the equation
regressor.fit(X_train, y_train)


# Let's see how the testing data does
y_pred = regressor.predict(X_test)


df_preds = pd.DataFrame({'Actual': y_test.squeeze(), 'Predicted': y_pred.squeeze()})
print("\nTest Results: Actual versus Predicted")
print(df_preds)


rsquared = r2_score(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
print("\nMetrics")
print(f'Root mean squared error: {rmse:.2f}')
# Out:
# Test Results: Actual versus Predicted
#      Actual      Predicted
# 0    155835  222263.738395
# 1    200100  222263.738395
# 2    339750  267671.292753
# 3    109000  131448.629679
# 4    149700  176856.184037
# ..      ...            ...
# 287  172500  131448.629679
# 288   98300  131448.629679
# 289  153500  176856.184037
# 290  187000  176856.184037
# 291  149900  131448.629679
#
# [292 rows x 2 columns]
#
# Metrics
# Root mean squared error: 44971.76
